# %% [markdown]
# # Membuat Data Dummy

# %%
import pandas as pd
import numpy as np

# %%
# Simulasi data penjualan
data = {
    'Tanggal': pd.date_range('2023-01-01', periods=200),
    'Produk': np.random.choice(['A', 'B', 'C'], size=200),
    'Jumlah': np.random.randint(1, 100, size=200),
    'Harga': np.random.uniform(10, 100, size=200)
}

df = pd.DataFrame(data)

# %% [markdown]
# ## Simple Exploration

# %%
df.head() # cek 5 baris awal
# Out:
#      Tanggal Produk  Jumlah      Harga
# 0 2023-01-01      C      14  43.474794
# 1 2023-01-02      B      25  59.960183
# 2 2023-01-03      B      38  24.906364
# 3 2023-01-04      B      19  41.583017
# 4 2023-01-05      C       3  65.267219

# %%
df.head(2) # cek 2 baris awal
# Out:
#      Tanggal Produk  Jumlah      Harga
# 0 2023-01-01      C      14  43.474794
# 1 2023-01-02      B      25  59.960183

# %%
df.tail() # cek 5 baris terakhir
# Out:
#        Tanggal Produk  Jumlah      Harga
# 360 2023-12-27      A      78  26.844277
# 361 2023-12-28      C      66  18.742321
# 362 2023-12-29      C       7  74.293350
# 363 2023-12-30      C      99  84.030741
# 364 2023-12-31      B      28  28.012613

# %%
df.sample() #ambil sample acak
# Out:
#        Tanggal Produk  Jumlah      Harga
# 113 2023-04-24      A      41  49.572982

# %%
df.info() # cek informasi data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  365 non-null    datetime64[ns]
#  1   Produk   365 non-null    object
#  2   Jumlah   365 non-null    int64
#  3   Harga    365 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 11.5+ KB

# %%
df.shape #cek jumlah baris dan kolom
# Out:
# (365, 4)

# %%
print('Jumlah baris:', df.shape[0])
print('Jumlah kolom:', df.shape[1])
# Out:
# Jumlah baris: 365
# Jumlah kolom: 4

# %%
# # mengatur opsi tampilan untuk menampilkan seluruh DataFrame
# pd.set_option('display.max_rows', None) #default 10 baris (head(5) & tail(5)
# pd.set_option('display.max_columns', None) #default 20 kolom
# pd.set_option('display.width', None) #default 80 karakter

# %% [markdown]
# Cara diatas adalah untuk menampilkan semua baris dan kolom . Cara tersebut tidak direkomendasikan karena akan memakan memori yang besar.

# %%
df.describe() #summary statistik
# Out:
#                    Tanggal      Jumlah       Harga
# count                  365  365.000000  365.000000
# mean   2023-07-02 00:00:00   51.021918   54.480055
# min    2023-01-01 00:00:00    1.000000   10.529620
# 25%    2023-04-02 00:00:00   25.000000   33.442714
# 50%    2023-07-02 00:00:00   52.000000   52.641156
# 75%    2023-10-01 00:00:00   77.000000   74.969509
# max    2023-12-31 00:00:00   99.000000   99.628012
# std                    NaN   30.098092   24.888523

# %%
# cek tipe data
df.dtypes
# Out:
# Tanggal    datetime64[ns]
# Produk             object
# Jumlah              int64
# Harga             float64
# dtype: object

# %%
# cek tipe data di kolom Tanggal
df['Tanggal'].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# `dtype('<M8[ns]')` adalah kode yang menunjukkan tipe data Datetime64[ns]. Ini adalah tipe data khusus dalam Pandas yang digunakan untuk merepresentasikan tanggal dan waktu dengan presisi nanosecond.
#
# Breakdown:
#
# - M8: Ini adalah kode untuk tipe data datetime.
# - [ns]: Ini menunjukkan bahwa presisi waktu adalah nanosecond.

# %%
# cek nama kolom
df.columns
# Out:
# Index(['Tanggal', 'Produk', 'Jumlah', 'Harga'], dtype='object')

# %%
# cek missing values
df.isnull().sum()
# Out:
# Tanggal    0
# Produk     0
# Jumlah     0
# Harga      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Tanggal    0
# Produk     0
# Jumlah     0
# Harga      0
# dtype: int64

# %%
df.nunique() #cek jumlah nilai yang unik
# Out:
# Tanggal    365
# Produk       3
# Jumlah      98
# Harga      365
# dtype: int64

# %%
print('Jenis Produk (Unik):', df['Produk'].unique())
print('Jumlah Produk yang Unik:', df['Produk'].nunique())
# Out:
# Jenis Produk (Unik): ['C' 'B' 'A']
# Jumlah Produk yang Unik: 3
# Jumlah Produk C: 124

# %%
# frekusi nilai unik pada setiap kolom
df['Produk'].value_counts()
# Out:
# Produk
# C    124
# A    123
# B    118
# Name: count, dtype: int64

# %%
# total produk C
print('Jumlah Produk C:', (df['Produk'] == 'C').sum())
# Out:
# Jumlah Produk C: 124

# %% [markdown]
# # Data Loading

# %% [markdown]
# ### From CSV File

# %%
# !wget https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/teams.csv
# Out:
# --2024-12-12 05:41:26--  https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/teams.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24958 (24K) [text/plain]
# Saving to: ‘teams.csv’
#
# teams.csv           100%[===================>]  24.37K  --.-KB/s    in 0.01s
#
# 2024-12-12 05:41:26 (2.50 MB/s) - ‘teams.csv’ saved [24958/24958]

# %%
teams = pd.read_csv('teams.csv')
teams.head()
# Out:
#                    division         conference  school_name  \
# 0  FBS (Division I-A Teams)  American Athletic   Cincinnati
# 1  FBS (Division I-A Teams)  American Athletic  Connecticut
# 2  FBS (Division I-A Teams)  American Athletic      Houston
# 3  FBS (Division I-A Teams)  American Athletic   Louisville
# 4  FBS (Division I-A Teams)  American Athletic      Memphis
#
#                                         roster_url  id
# 0  http://espn.go.com/ncf/teams/roster?teamId=2132   1
# 1    http://espn.go.com/ncf/teams/roster?teamId=41   2
# 2   http://espn.go.com/ncf/teams/roster?teamId=248   3
# 3    http://espn.go.com/ncf/teams/roster?teamId=97   4
# 4   http://espn.go.com/ncf/teams/roster?teamId=235   5

# %%
# load data dari link
house = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/kc_house_data.csv')
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### From TSV File

# %%
tsv_df = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/cities_world.tsv',
                     delimiter='\t')
tsv_df.head()
# Out:
#              City  Latitude  Longitude      Country  Population  Land_area  \
# 0  Tokyo/Yokohama   35.6895   139.6917        Japan    33200000       6993
# 1  New York Metro   40.7128   -74.0059          USA    17800000       8683
# 2       Sao Paulo  -23.5505   -46.6333       Brazil    17700000       1968
# 3   Seoul/Incheon   37.5665   126.9780  South Korea    17500000       1049
# 4     Mexico City   23.6345  -102.5528       Mexico    17400000       2072
#
#    Density  Number
# 0     4750       1
# 1     2050       2
# 2     9000       3
# 3    16700       4
# 4     8400       5

# %% [markdown]
# ### From Excel File

# %%
file = 'https://github.com/FTDS-learning-materials/phase-0/raw/main/src/data_penjualan.xlsx'
sales = pd.read_excel(file)
sales.head()
# Out:
#       Bulan  Penjualan
# 0   Januari       1000
# 1  Februari        200
# 2     Maret       5000
# 3     April        654
# 4       Mei       1200

# %% [markdown]
# Ingatlah bahwa file excel dapat memiliki lebih dari satu lembar (sheet). Jadi, bagaimana cara memeriksa lembar-lembar dalam file excel?

# %%
pd.ExcelFile(file).sheet_names
# Out:
# ['2020', '2021']

# %% [markdown]
# Untuk membuka lembar tertentu, Anda dapat menambahkan `sheet_name` argumen saat menggunakan `pd.read_excel`. Perhatikan bahwa secara default, `pd.read_excel` akan membuka lembar pertama.

# %%
sales = pd.read_excel(file,sheet_name='2021')
sales.head()
# Out:
#       Bulan  Penjualan
# 0   Januari       1200
# 1  Februari       1500
# 2     Maret       4000
# 3     April       7600
# 4       Mei       1200

# %% [markdown]
# # Latihan - Dataset Superstore

# %% [markdown]
# Pada latihan ini kita akan melakukan explorasi dengan dataset superstore yang didapatkan dari Kaggle. Berikut adalah link datasetnya: https://www.kaggle.com/datasets/vivek468/superstore-dataset-final/data

# %%
#Buat folder di kaggle root
# !mkdir ~/.kaggle
# copy-paster kaggle.json ke folder kaggle
# !cp '/content/drive/MyDrive/DTS Resources/kaggle/kaggle.json' ~/.kaggle

# !chmod 600 ~/.kaggle/kaggle.json #perizinan akses, hanya pemilik file yang memiliki akses baca dan tulis ke file
# !ls ~/.kaggle #cek list data yang ada di folder kaggle

# %%
# !kaggle datasets download vivek468/superstore-dataset-final
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vivek468/superstore-dataset-final
# License(s): other
# Downloading superstore-dataset-final.zip to /content
# 100% 550k/550k [00:00<00:00, 956kB/s]
# 100% 550k/550k [00:00<00:00, 955kB/s]

# %%
# !unzip superstore-dataset-final.zip
# Out:
# Archive:  superstore-dataset-final.zip
#   inflating: Sample - Superstore.csv

# %%
# read csv
df = pd.read_csv('Sample - Superstore.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-53-2ce4de7a298f> in <cell line: 2>()
#       1 # read csv
# ----> 2 df = pd.read_csv('/content/Sample - Superstore.csv')
#       3 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      91             # Fail here loudly instead of in cython after reading
#      92             import_optional_dependency("pyarrow")
# ---> 93         self._reader = parsers.TextReader(src, **kwds)
#      94
#      95         self.unnamed_cols = self._reader.unnamed_cols
#
# parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 2944: invalid start byte

# %% [markdown]
# Di sini kita terdapat eror karena masalah encoding yang digunakan bukan `utf-8` maka kita butuh menyesuaikannya terlebih dahulu

# %%
# !pip -q install chardet #library untuk cek unicode
# Out:
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (5.2.0)

# %%
import chardet
# membaca file dan menentukan encoding-nya
file_path= 'Sample - Superstore.csv'
with open(file_path, 'rb') as f:
    result = chardet.detect(f.read())
    encoding = result['encoding']

# menampilkan hasil encoding
print('Encoding file:', encoding)
# Out:
# Encoding file: Windows-1252

# %%
# read csv
df =  pd.read_csv(file_path, encoding='Windows-1252')
df.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Rename, Set Index, Reset Index

# %%
# ubah nama kolom
df.rename(columns={'Row ID': 'row_id',
                   'Order ID': 'order_id',
                   'Order Date': 'order_date'}
          , inplace=True)
df.head(2)
# Out:
#    row_id        order_id order_date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
# ubah semua nama kolom agar lower case dan tanpa spasi
df.columns = df.columns.str.lower().str.replace(' ', '_')

#replace juga tanda '-' menjadi '_'
df.columns = df.columns.str.replace('-', '_')
df.head(2)
# Out:
#    row_id        order_id order_date   ship_date     ship_mode customer_id  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   customer_name   segment        country       city  ... postal_code  region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         product_id   category sub_category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         product_name   sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    discount    profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
# set row_id sebagi index
df.set_index('row_id', inplace=True)
df.head(2)
# Out:
#               order_id order_date   ship_date     ship_mode customer_id  \
# row_id
# 1       CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 2       CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#        customer_name   segment        country       city     state  \
# row_id
# 1        Claire Gute  Consumer  United States  Henderson  Kentucky
# 2        Claire Gute  Consumer  United States  Henderson  Kentucky
#
#         postal_code region       product_id   category sub_category  \
# row_id
# 1             42420  South  FUR-BO-10001798  Furniture    Bookcases
# 2             42420  South  FUR-CH-10000454  Furniture       Chairs
#
#                                              product_name   sales  quantity  \
# row_id
# 1                       Bush Somerset Collection Bookcase  261.96         2
# 2       Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#         discount    profit
# row_id
# 1            0.0   41.9136
# 2            0.0  219.5820

# %%
#drop original index dan simpan hasilnya ke variabel df_re
df_re = df.reset_index(drop=True)
df_re.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
#Ubah objek df yg asli dengan inplace+True tanpa buat df baru
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ## Slicing - Akses baris dan Kolom

# %%
df['city'] #single column
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: city, Length: 9994, dtype: object

# %%
df[['country','city']] #multiple columns
# Out:
#             country             city
# 0     United States        Henderson
# 1     United States        Henderson
# 2     United States      Los Angeles
# 3     United States  Fort Lauderdale
# 4     United States  Fort Lauderdale
# ...             ...              ...
# 9989  United States            Miami
# 9990  United States       Costa Mesa
# 9991  United States       Costa Mesa
# 9992  United States       Costa Mesa
# 9993  United States      Westminster
#
# [9994 rows x 2 columns]

# %% [markdown]
# Akses baris dan kolom dengan iloc dan loc:
#
# - `iloc`: iloc adalah singkatan dari "integer location" dan digunakan untuk mengakses data berdasarkan indeks baris dan kolom dalam DataFrame atau Series secara eksplisit menggunakan indeks integer. Indeks dimulai dari angka 0 untuk baris/kolom pertama.
#
# - `loc`: loc adalah singkatan dari "label location" dan digunakan untuk mengakses data berdasarkan label baris dan kolom dalam DataFrame atau Series. Ini berarti Anda dapat menggunakan label yang ditetapkan untuk baris/kolom untuk mengakses elemen yang sesuai.

# %%
df.head(2)
# Out:
#          order_id order_date   ship_date     ship_mode customer_id  \
# 0  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   customer_name   segment        country       city     state  postal_code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky        42420
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky        42420
#
#   region       product_id   category sub_category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         product_name   sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    discount    profit
# 0       0.0   41.9136
# 1       0.0  219.5820

# %%
# Mengakses elemen pada baris index ke-0, kolom index ke-1
print(df.iloc[0, 1])
print(df.loc[0,'order_date'])
# Out:
# 11/8/2016
# 11/8/2016

# %%
# mengakses kolom order_id hingga ship_date menggunakan loc
df.loc[:,'order_id':'ship_date'].head()
# Out:
#          order_id  order_date   ship_date
# 0  CA-2016-152156   11/8/2016  11/11/2016
# 1  CA-2016-152156   11/8/2016  11/11/2016
# 2  CA-2016-138688   6/12/2016   6/16/2016
# 3  US-2015-108966  10/11/2015  10/18/2015
# 4  US-2015-108966  10/11/2015  10/18/2015

# %%
# mengakses kolom order_id hingga ship_date menggunakan iloc
df.iloc[:,0:3].head()
# Out:
#          order_id  order_date   ship_date
# 0  CA-2016-152156   11/8/2016  11/11/2016
# 1  CA-2016-152156   11/8/2016  11/11/2016
# 2  CA-2016-138688   6/12/2016   6/16/2016
# 3  US-2015-108966  10/11/2015  10/18/2015
# 4  US-2015-108966  10/11/2015  10/18/2015

# %%
df.iloc[:5,] #baris ke 1-5 (index 0-4), kolom index awal-akhir
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.loc[:4,]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# Kita juga dapat menggunakan `np.r_` untuk menggabungkan dua daerah indeks, seperti contoh berikut ini:

# %%
#baris index 1-2 dan kolom index 0-1 dan kolom index 4-6
df.iloc[1:3, np.r_[0:2, 4:7]]
# Out:
#          order_id order_date customer_id    customer_name    segment
# 1  CA-2016-152156  11/8/2016    CG-12520      Claire Gute   Consumer
# 2  CA-2016-138688  6/12/2016    DV-13045  Darrin Van Huff  Corporate

# %%
df_new= df.set_index('segment')
df_new.head()
# Out:
#                  order_id  order_date   ship_date       ship_mode customer_id  \
# segment
# Consumer   CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# Consumer   CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# Corporate  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# Consumer   US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# Consumer   US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#              customer_name        country             city       state  \
# segment
# Consumer       Claire Gute  United States        Henderson    Kentucky
# Consumer       Claire Gute  United States        Henderson    Kentucky
# Corporate  Darrin Van Huff  United States      Los Angeles  California
# Consumer    Sean O'Donnell  United States  Fort Lauderdale     Florida
# Consumer    Sean O'Donnell  United States  Fort Lauderdale     Florida
#
#            postal_code region       product_id         category sub_category  \
# segment
# Consumer         42420  South  FUR-BO-10001798        Furniture    Bookcases
# Consumer         42420  South  FUR-CH-10000454        Furniture       Chairs
# Corporate        90036   West  OFF-LA-10000240  Office Supplies       Labels
# Consumer         33311  South  FUR-TA-10000577        Furniture       Tables
# Consumer         33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                                 product_name     sales  \
# segment
# Consumer                   Bush Somerset Collection Bookcase  261.9600
# Consumer   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# Corporate  Self-Adhesive Address Labels for Typewriters b...   14.6200
# Consumer       Bretford CR4500 Series Slim Rectangular Table  957.5775
# Consumer                      Eldon Fold 'N Roll Cart System   22.3680
#
#            quantity  discount    profit
# segment
# Consumer          2      0.00   41.9136
# Consumer          3      0.00  219.5820
# Corporate         2      0.00    6.8714
# Consumer          5      0.45 -383.0310
# Consumer          2      0.20    2.5164

# %%
df_new.index.unique()
# Out:
# Index(['Consumer', 'Corporate', 'Home Office'], dtype='object', name='segment')

# %% [markdown]
# menggunakan `loc` akan memudahkan kita jika index yang digunakan dalam bentuk label atau nama.

# %%
df_new.loc['Corporate'].head()
# Out:
#                  order_id order_date   ship_date       ship_mode customer_id  \
# segment
# Corporate  CA-2016-138688  6/12/2016   6/16/2016    Second Class    DV-13045
# Corporate  CA-2016-137330  12/9/2016  12/13/2016  Standard Class    KB-16585
# Corporate  CA-2016-137330  12/9/2016  12/13/2016  Standard Class    KB-16585
# Corporate  CA-2016-117590  12/8/2016  12/10/2016     First Class    GH-14485
# Corporate  CA-2016-117590  12/8/2016  12/10/2016     First Class    GH-14485
#
#              customer_name        country         city       state  \
# segment
# Corporate  Darrin Van Huff  United States  Los Angeles  California
# Corporate        Ken Black  United States      Fremont    Nebraska
# Corporate        Ken Black  United States      Fremont    Nebraska
# Corporate        Gene Hale  United States   Richardson       Texas
# Corporate        Gene Hale  United States   Richardson       Texas
#
#            postal_code   region       product_id         category  \
# segment
# Corporate        90036     West  OFF-LA-10000240  Office Supplies
# Corporate        68025  Central  OFF-AR-10000246  Office Supplies
# Corporate        68025  Central  OFF-AP-10001492  Office Supplies
# Corporate        75080  Central  TEC-PH-10004977       Technology
# Corporate        75080  Central  FUR-FU-10003664        Furniture
#
#           sub_category                                       product_name  \
# segment
# Corporate       Labels  Self-Adhesive Address Labels for Typewriters b...
# Corporate          Art                                         Newell 318
# Corporate   Appliances        Acco Six-Outlet Power Strip, 4' Cord Length
# Corporate       Phones                                        GE 30524EE4
# Corporate  Furnishings  Electrix Architect's Clamp-On Swing Arm Lamp, ...
#
#               sales  quantity  discount    profit
# segment
# Corporate    14.620         2       0.0    6.8714
# Corporate    19.460         7       0.0    5.0596
# Corporate    60.340         7       0.0   15.6884
# Corporate  1097.544         7       0.2  123.4737
# Corporate   190.920         5       0.6 -147.9630

# %% [markdown]
# ## Query/Filtering

# %%
# cek customer_name `Darrin Van Huff`
df[df['customer_name'] == 'Darrin Van Huff']
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 2976  CA-2017-139773   12/4/2017   12/4/2017        Same Day    DV-13045
# 5298  CA-2016-106656   9/23/2016   9/26/2016     First Class    DV-13045
# 5299  CA-2016-106656   9/23/2016   9/26/2016     First Class    DV-13045
# 5617  CA-2017-125745   6/30/2017    7/4/2017  Standard Class    DV-13045
# 7344  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
# 7345  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
# 7346  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
# 7347  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
#
#         customer_name    segment        country          city         state  \
# 2     Darrin Van Huff  Corporate  United States   Los Angeles    California
# 2976  Darrin Van Huff  Corporate  United States  Philadelphia  Pennsylvania
# 5298  Darrin Van Huff  Corporate  United States     San Diego    California
# 5299  Darrin Van Huff  Corporate  United States     San Diego    California
# 5617  Darrin Van Huff  Corporate  United States       Memphis     Tennessee
# 7344  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
# 7345  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
# 7346  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
# 7347  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
#
#       postal_code region       product_id         category sub_category  \
# 2           90036   West  OFF-LA-10000240  Office Supplies       Labels
# 2976        19143   East  FUR-CH-10001797        Furniture       Chairs
# 5298        92037   West  OFF-EN-10001509  Office Supplies    Envelopes
# 5299        92037   West  OFF-LA-10003148  Office Supplies       Labels
# 5617        38109  South  FUR-FU-10001591        Furniture  Furnishings
# 7344        32216  South  FUR-TA-10004289        Furniture       Tables
# 7345        32216  South  TEC-PH-10003555       Technology       Phones
# 7346        32216  South  OFF-AR-10001958  Office Supplies          Art
# 7347        32216  South  FUR-CH-10000225        Furniture       Chairs
#
#                                            product_name    sales  quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 2976                   Safco Chair Connectors, 6/Carton  188.552         7
# 5298                          Poly String Tie Envelopes    4.080         2
# 5299                                           Avery 51   18.900         3
# 5617    Advantus Panel Wall Certificate Holder - 8.5x11   19.520         2
# 7344  BoxOffice By Design Rectangular and Half-Moon ...  721.875         6
# 7345         Motorola HK250 Universal Bluetooth Headset   73.568         4
# 7346  Stanley Bostitch Contemporary Electric Pencil ...   13.584         1
# 7347                 Global Geo Office Task Chair, Gray   64.784         1
#
#       discount    profit
# 2         0.00    6.8714
# 2976      0.30   -2.6936
# 5298      0.00    1.9176
# 5299      0.00    8.6940
# 5617      0.20    5.3680
# 7344      0.45 -420.0000
# 7345      0.20  -16.5528
# 7346      0.20    1.3584
# 7347      0.20  -12.1470

# %%
# cek customer_name `Darrin Van Huff` dengan .query
df.query('customer_name == "Darrin Van Huff"')
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 2976  CA-2017-139773   12/4/2017   12/4/2017        Same Day    DV-13045
# 5298  CA-2016-106656   9/23/2016   9/26/2016     First Class    DV-13045
# 5299  CA-2016-106656   9/23/2016   9/26/2016     First Class    DV-13045
# 5617  CA-2017-125745   6/30/2017    7/4/2017  Standard Class    DV-13045
# 7344  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
# 7345  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
# 7346  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
# 7347  CA-2017-168389  12/11/2017  12/17/2017  Standard Class    DV-13045
#
#         customer_name    segment        country          city         state  \
# 2     Darrin Van Huff  Corporate  United States   Los Angeles    California
# 2976  Darrin Van Huff  Corporate  United States  Philadelphia  Pennsylvania
# 5298  Darrin Van Huff  Corporate  United States     San Diego    California
# 5299  Darrin Van Huff  Corporate  United States     San Diego    California
# 5617  Darrin Van Huff  Corporate  United States       Memphis     Tennessee
# 7344  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
# 7345  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
# 7346  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
# 7347  Darrin Van Huff  Corporate  United States  Jacksonville       Florida
#
#       postal_code region       product_id         category sub_category  \
# 2           90036   West  OFF-LA-10000240  Office Supplies       Labels
# 2976        19143   East  FUR-CH-10001797        Furniture       Chairs
# 5298        92037   West  OFF-EN-10001509  Office Supplies    Envelopes
# 5299        92037   West  OFF-LA-10003148  Office Supplies       Labels
# 5617        38109  South  FUR-FU-10001591        Furniture  Furnishings
# 7344        32216  South  FUR-TA-10004289        Furniture       Tables
# 7345        32216  South  TEC-PH-10003555       Technology       Phones
# 7346        32216  South  OFF-AR-10001958  Office Supplies          Art
# 7347        32216  South  FUR-CH-10000225        Furniture       Chairs
#
#                                            product_name    sales  quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 2976                   Safco Chair Connectors, 6/Carton  188.552         7
# 5298                          Poly String Tie Envelopes    4.080         2
# 5299                                           Avery 51   18.900         3
# 5617    Advantus Panel Wall Certificate Holder - 8.5x11   19.520         2
# 7344  BoxOffice By Design Rectangular and Half-Moon ...  721.875         6
# 7345         Motorola HK250 Universal Bluetooth Headset   73.568         4
# 7346  Stanley Bostitch Contemporary Electric Pencil ...   13.584         1
# 7347                 Global Geo Office Task Chair, Gray   64.784         1
#
#       discount    profit
# 2         0.00    6.8714
# 2976      0.30   -2.6936
# 5298      0.00    1.9176
# 5299      0.00    8.6940
# 5617      0.20    5.3680
# 7344      0.45 -420.0000
# 7345      0.20  -16.5528
# 7346      0.20    1.3584
# 7347      0.20  -12.1470

# %%
# cek profit yang nilainya dibawah 0 atau minus
df[df['profit'] < 0]
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 14    US-2015-118983  11/22/2015  11/26/2015  Standard Class    HP-14815
# 15    US-2015-118983  11/22/2015  11/26/2015  Standard Class    HP-14815
# 23    US-2017-156909   7/16/2017   7/18/2017    Second Class    SF-20065
# 27    US-2015-150630   9/17/2015   9/21/2015  Standard Class    TB-21520
# ...              ...         ...         ...             ...         ...
# 9920  CA-2016-149272   3/15/2016   3/19/2016  Standard Class    MY-18295
# 9921  CA-2014-111360  11/24/2014  11/30/2014  Standard Class    AT-10435
# 9931  CA-2015-104948  11/13/2015  11/17/2015  Standard Class    KH-16510
# 9937  CA-2016-164889    6/3/2016    6/6/2016    Second Class    CP-12340
# 9962  CA-2015-168088   3/19/2015   3/22/2015     First Class    CM-12655
#
#          customer_name      segment        country             city  \
# 3       Sean O'Donnell     Consumer  United States  Fort Lauderdale
# 14       Harold Pawlan  Home Office  United States       Fort Worth
# 15       Harold Pawlan  Home Office  United States       Fort Worth
# 23     Sandra Flanagan     Consumer  United States     Philadelphia
# 27     Tracy Blumstein     Consumer  United States     Philadelphia
# ...                ...          ...            ...              ...
# 9920   Muhammed Yedwab    Corporate  United States            Bryan
# 9921       Alyssa Tate  Home Office  United States            Akron
# 9931     Keith Herrera     Consumer  United States   San Bernardino
# 9937    Christine Phan    Corporate  United States      Los Angeles
# 9962  Corinna Mitchell  Home Office  United States          Houston
#
#              state  postal_code   region       product_id         category  \
# 3          Florida        33311    South  FUR-TA-10000577        Furniture
# 14           Texas        76106  Central  OFF-AP-10002311  Office Supplies
# 15           Texas        76106  Central  OFF-BI-10000756  Office Supplies
# 23    Pennsylvania        19140     East  FUR-CH-10002774        Furniture
# 27    Pennsylvania        19140     East  FUR-BO-10004834        Furniture
# ...            ...          ...      ...              ...              ...
# 9920         Texas        77803  Central  OFF-BI-10004233  Office Supplies
# 9921          Ohio        44312     East  OFF-BI-10003350  Office Supplies
# 9931    California        92404     West  FUR-BO-10004357        Furniture
# 9937    California        90049     West  FUR-TA-10001676        Furniture
# 9962         Texas        77041  Central  FUR-BO-10004218        Furniture
#
#      sub_category                                       product_name  \
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table
# 14     Appliances  Holmes Replacement Filter for HEPA Air Cleaner...
# 15        Binders   Storex DuraTech Recycled Plastic Frosted Binders
# 23         Chairs                 Global Deluxe Stacking Chair, Gray
# 27      Bookcases  Riverside Palais Royal Lawyers Bookcase, Royal...
# ...           ...                                                ...
# 9920      Binders  GBC Pre-Punched Binding Paper, Plastic, White,...
# 9921      Binders                    Acco Expandable Hanging Binders
# 9931    Bookcases     O'Sullivan Living Dimensions 3-Shelf Bookcases
# 9937       Tables       Hon 61000 Series Interactive Training Tables
# 9962    Bookcases  Bush Heritage Pine Collection 5-Shelf Bookcase...
#
#           sales  quantity  discount     profit
# 3      957.5775         5      0.45  -383.0310
# 14      68.8100         5      0.80  -123.8580
# 15       2.5440         3      0.80    -3.8160
# 23      71.3720         2      0.30    -1.0196
# 27    3083.4300         7      0.50 -1665.0522
# ...         ...       ...       ...        ...
# 9920    22.3860         7      0.80   -35.8176
# 9921     5.7420         3      0.70    -4.5936
# 9931   683.3320         4      0.15   -40.1960
# 9937    71.0880         2      0.20    -1.7772
# 9962   383.4656         4      0.32   -67.6704
#
# [1871 rows x 20 columns]

# %%
# cek profit yang nilainya dibawah 0 dan statenya Texas
df[(df['profit'] < 0) & (df['state'] == 'Texas')]
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 14    US-2015-118983  11/22/2015  11/26/2015  Standard Class    HP-14815
# 15    US-2015-118983  11/22/2015  11/26/2015  Standard Class    HP-14815
# 36    CA-2016-117590   12/8/2016  12/10/2016     First Class    GH-14485
# 38    CA-2015-117415  12/27/2015  12/31/2015  Standard Class    SN-20710
# 39    CA-2015-117415  12/27/2015  12/31/2015  Standard Class    SN-20710
# ...              ...         ...         ...             ...         ...
# 9835  CA-2016-126627  10/10/2016  10/12/2016     First Class    WB-21850
# 9903  CA-2014-122609  11/12/2014  11/18/2014  Standard Class    DP-13000
# 9919  CA-2016-149272   3/15/2016   3/19/2016  Standard Class    MY-18295
# 9920  CA-2016-149272   3/15/2016   3/19/2016  Standard Class    MY-18295
# 9962  CA-2015-168088   3/19/2015   3/22/2015     First Class    CM-12655
#
#          customer_name      segment        country        city  state  \
# 14       Harold Pawlan  Home Office  United States  Fort Worth  Texas
# 15       Harold Pawlan  Home Office  United States  Fort Worth  Texas
# 36           Gene Hale    Corporate  United States  Richardson  Texas
# 38        Steve Nguyen  Home Office  United States     Houston  Texas
# 39        Steve Nguyen  Home Office  United States     Houston  Texas
# ...                ...          ...            ...         ...    ...
# 9835     William Brown     Consumer  United States    La Porte  Texas
# 9903     Darren Powers     Consumer  United States  Carrollton  Texas
# 9919   Muhammed Yedwab    Corporate  United States       Bryan  Texas
# 9920   Muhammed Yedwab    Corporate  United States       Bryan  Texas
# 9962  Corinna Mitchell  Home Office  United States     Houston  Texas
#
#       postal_code   region       product_id         category sub_category  \
# 14          76106  Central  OFF-AP-10002311  Office Supplies   Appliances
# 15          76106  Central  OFF-BI-10000756  Office Supplies      Binders
# 36          75080  Central  FUR-FU-10003664        Furniture  Furnishings
# 38          77041  Central  FUR-BO-10002545        Furniture    Bookcases
# 39          77041  Central  FUR-CH-10004218        Furniture       Chairs
# ...           ...      ...              ...              ...          ...
# 9835        77571  Central  OFF-BI-10001597  Office Supplies      Binders
# 9903        75007  Central  FUR-FU-10004587        Furniture  Furnishings
# 9919        77803  Central  FUR-CH-10000863        Furniture       Chairs
# 9920        77803  Central  OFF-BI-10004233  Office Supplies      Binders
# 9962        77041  Central  FUR-BO-10004218        Furniture    Bookcases
#
#                                            product_name     sales  quantity  \
# 14    Holmes Replacement Filter for HEPA Air Cleaner...   68.8100         5
# 15     Storex DuraTech Recycled Plastic Frosted Binders    2.5440         3
# 36    Electrix Architect's Clamp-On Swing Arm Lamp, ...  190.9200         5
# 38    Atlantic Metals Mobile 3-Shelf Bookcases, Cust...  532.3992         3
# 39             Global Fabric Manager's Chair, Dark Gray  212.0580         3
# ...                                                 ...       ...       ...
# 9835  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...   16.3920         2
# 9903  GE General Use Halogen Bulbs, 100 Watts, 1 Bul...   25.1280         3
# 9919                   Novimex Swivel Fabric Task Chair  528.4300         5
# 9920  GBC Pre-Punched Binding Paper, Plastic, White,...   22.3860         7
# 9962  Bush Heritage Pine Collection 5-Shelf Bookcase...  383.4656         4
#
#       discount    profit
# 14        0.80 -123.8580
# 15        0.80   -3.8160
# 36        0.60 -147.9630
# 38        0.32  -46.9764
# 39        0.30  -15.1470
# ...        ...       ...
# 9835      0.80  -26.2272
# 9903      0.60   -6.9102
# 9919      0.30 -143.4310
# 9920      0.80  -35.8176
# 9962      0.32  -67.6704
#
# [486 rows x 20 columns]

# %%
# cek state yang berada di texas dan california
df[df['state'].isin(['Texas', 'California'])]
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 2     CA-2016-138688  6/12/2016  6/16/2016    Second Class    DV-13045
# 5     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 6     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 7     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 8     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# ...              ...        ...        ...             ...         ...
# 9986  CA-2016-125794  9/29/2016  10/3/2016  Standard Class    ML-17410
# 9990  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914   5/4/2017   5/9/2017    Second Class    CC-12220
#
#         customer_name    segment        country         city       state  \
# 2     Darrin Van Huff  Corporate  United States  Los Angeles  California
# 5     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 6     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 7     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 8     Brosina Hoffman   Consumer  United States  Los Angeles  California
# ...               ...        ...            ...          ...         ...
# 9986     Maris LaWare   Consumer  United States  Los Angeles  California
# 9990      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9991      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9992      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9993     Chris Cortes   Consumer  United States  Westminster  California
#
#       postal_code region       product_id         category sub_category  \
# 2           90036   West  OFF-LA-10000240  Office Supplies       Labels
# 5           90032   West  FUR-FU-10001487        Furniture  Furnishings
# 6           90032   West  OFF-AR-10002833  Office Supplies          Art
# 7           90032   West  TEC-PH-10002275       Technology       Phones
# 8           90032   West  OFF-BI-10003910  Office Supplies      Binders
# ...           ...    ...              ...              ...          ...
# 9986        90008   West  TEC-AC-10003399       Technology  Accessories
# 9990        92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991        92627   West  TEC-PH-10003645       Technology       Phones
# 9992        92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993        92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name    sales  quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                            Newell 322    7.280         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 8     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       discount   profit
# 2          0.0   6.8714
# 5          0.0  14.1694
# 6          0.0   1.9656
# 7          0.2  90.7152
# 8          0.2   5.7825
# ...        ...      ...
# 9986       0.0  15.2208
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [2986 rows x 20 columns]

# %%
# cek state yang berada di texas dan california dengan query
df.query('state in ["Texas", "California"]')
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 2     CA-2016-138688  6/12/2016  6/16/2016    Second Class    DV-13045
# 5     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 6     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 7     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 8     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# ...              ...        ...        ...             ...         ...
# 9986  CA-2016-125794  9/29/2016  10/3/2016  Standard Class    ML-17410
# 9990  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914   5/4/2017   5/9/2017    Second Class    CC-12220
#
#         customer_name    segment        country         city       state  \
# 2     Darrin Van Huff  Corporate  United States  Los Angeles  California
# 5     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 6     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 7     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 8     Brosina Hoffman   Consumer  United States  Los Angeles  California
# ...               ...        ...            ...          ...         ...
# 9986     Maris LaWare   Consumer  United States  Los Angeles  California
# 9990      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9991      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9992      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9993     Chris Cortes   Consumer  United States  Westminster  California
#
#       postal_code region       product_id         category sub_category  \
# 2           90036   West  OFF-LA-10000240  Office Supplies       Labels
# 5           90032   West  FUR-FU-10001487        Furniture  Furnishings
# 6           90032   West  OFF-AR-10002833  Office Supplies          Art
# 7           90032   West  TEC-PH-10002275       Technology       Phones
# 8           90032   West  OFF-BI-10003910  Office Supplies      Binders
# ...           ...    ...              ...              ...          ...
# 9986        90008   West  TEC-AC-10003399       Technology  Accessories
# 9990        92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991        92627   West  TEC-PH-10003645       Technology       Phones
# 9992        92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993        92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name    sales  quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                            Newell 322    7.280         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 8     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       discount   profit
# 2          0.0   6.8714
# 5          0.0  14.1694
# 6          0.0   1.9656
# 7          0.2  90.7152
# 8          0.2   5.7825
# ...        ...      ...
# 9986       0.0  15.2208
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [2986 rows x 20 columns]

# %%
# cek state yang berada di texas dan california dengan query
list_state= ['Texas', 'California']
df.query('state in @list_state')
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 2     CA-2016-138688  6/12/2016  6/16/2016    Second Class    DV-13045
# 5     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 6     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 7     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# 8     CA-2014-115812   6/9/2014  6/14/2014  Standard Class    BH-11710
# ...              ...        ...        ...             ...         ...
# 9986  CA-2016-125794  9/29/2016  10/3/2016  Standard Class    ML-17410
# 9990  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914   5/4/2017   5/9/2017    Second Class    CC-12220
#
#         customer_name    segment        country         city       state  \
# 2     Darrin Van Huff  Corporate  United States  Los Angeles  California
# 5     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 6     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 7     Brosina Hoffman   Consumer  United States  Los Angeles  California
# 8     Brosina Hoffman   Consumer  United States  Los Angeles  California
# ...               ...        ...            ...          ...         ...
# 9986     Maris LaWare   Consumer  United States  Los Angeles  California
# 9990      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9991      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9992      Dave Brooks   Consumer  United States   Costa Mesa  California
# 9993     Chris Cortes   Consumer  United States  Westminster  California
#
#       postal_code region       product_id         category sub_category  \
# 2           90036   West  OFF-LA-10000240  Office Supplies       Labels
# 5           90032   West  FUR-FU-10001487        Furniture  Furnishings
# 6           90032   West  OFF-AR-10002833  Office Supplies          Art
# 7           90032   West  TEC-PH-10002275       Technology       Phones
# 8           90032   West  OFF-BI-10003910  Office Supplies      Binders
# ...           ...    ...              ...              ...          ...
# 9986        90008   West  TEC-AC-10003399       Technology  Accessories
# 9990        92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991        92627   West  TEC-PH-10003645       Technology       Phones
# 9992        92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993        92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name    sales  quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                            Newell 322    7.280         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 8     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       discount   profit
# 2          0.0   6.8714
# 5          0.0  14.1694
# 6          0.0   1.9656
# 7          0.2  90.7152
# 8          0.2   5.7825
# ...        ...      ...
# 9986       0.0  15.2208
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [2986 rows x 20 columns]

# %%
# cek state yang berada selain  texas dan california
df[~df['state'].isin(['Texas', 'California'])]
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 12    CA-2017-114412   4/15/2017   4/20/2017  Standard Class    AA-10480
# ...              ...         ...         ...             ...         ...
# 9984  CA-2015-100251   5/17/2015   5/23/2015  Standard Class    DV-13465
# 9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class    DV-13465
# 9987  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
#
#          customer_name    segment        country             city  \
# 0          Claire Gute   Consumer  United States        Henderson
# 1          Claire Gute   Consumer  United States        Henderson
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 12        Andrew Allen   Consumer  United States          Concord
# ...                ...        ...            ...              ...
# 9984  Dianna Vittorini   Consumer  United States       Long Beach
# 9985  Dianna Vittorini   Consumer  United States       Long Beach
# 9987      Ruben Ausman  Corporate  United States           Athens
# 9988      Ruben Ausman  Corporate  United States           Athens
# 9989  Tom Boeckenhauer   Consumer  United States            Miami
#
#                state  postal_code region       product_id         category  \
# 0           Kentucky        42420  South  FUR-BO-10001798        Furniture
# 1           Kentucky        42420  South  FUR-CH-10000454        Furniture
# 3            Florida        33311  South  FUR-TA-10000577        Furniture
# 4            Florida        33311  South  OFF-ST-10000760  Office Supplies
# 12    North Carolina        28027  South  OFF-PA-10002365  Office Supplies
# ...              ...          ...    ...              ...              ...
# 9984        New York        11561   East  OFF-LA-10003766  Office Supplies
# 9985        New York        11561   East  OFF-SU-10000898  Office Supplies
# 9987         Georgia        30605  South  TEC-AC-10001539       Technology
# 9988         Georgia        30605  South  TEC-PH-10004006       Technology
# 9989         Florida        33180  South  FUR-FU-10001889        Furniture
#
#      sub_category                                       product_name  \
# 0       Bookcases                  Bush Somerset Collection Bookcase
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table
# 4         Storage                     Eldon Fold 'N Roll Cart System
# 12          Paper                                         Xerox 1967
# ...           ...                                                ...
# 9984       Labels                     Self-Adhesive Removable Labels
# 9985     Supplies  Acme Hot Forged Carbon Steel Scissors with Nic...
# 9987  Accessories  Logitech G430 Surround Sound Gaming Headset wi...
# 9988       Phones                    Panasonic KX - TS880B Telephone
# 9989  Furnishings                             Ultra Door Pull Handle
#
#          sales  quantity  discount    profit
# 0     261.9600         2      0.00   41.9136
# 1     731.9400         3      0.00  219.5820
# 3     957.5775         5      0.45 -383.0310
# 4      22.3680         2      0.20    2.5164
# 12     15.5520         3      0.20    5.4432
# ...        ...       ...       ...       ...
# 9984   31.5000        10      0.00   15.1200
# 9985   55.6000         4      0.00   16.1240
# 9987   79.9900         1      0.00   28.7964
# 9988  206.1000         5      0.00   55.6470
# 9989   25.2480         3      0.20    4.1028
#
# [7008 rows x 20 columns]

# %%
# cek state yang berada selain texas dan california  dengan query
df.query('state not in ["Texas", "California"]')
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 12    CA-2017-114412   4/15/2017   4/20/2017  Standard Class    AA-10480
# ...              ...         ...         ...             ...         ...
# 9984  CA-2015-100251   5/17/2015   5/23/2015  Standard Class    DV-13465
# 9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class    DV-13465
# 9987  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
#
#          customer_name    segment        country             city  \
# 0          Claire Gute   Consumer  United States        Henderson
# 1          Claire Gute   Consumer  United States        Henderson
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 12        Andrew Allen   Consumer  United States          Concord
# ...                ...        ...            ...              ...
# 9984  Dianna Vittorini   Consumer  United States       Long Beach
# 9985  Dianna Vittorini   Consumer  United States       Long Beach
# 9987      Ruben Ausman  Corporate  United States           Athens
# 9988      Ruben Ausman  Corporate  United States           Athens
# 9989  Tom Boeckenhauer   Consumer  United States            Miami
#
#                state  postal_code region       product_id         category  \
# 0           Kentucky        42420  South  FUR-BO-10001798        Furniture
# 1           Kentucky        42420  South  FUR-CH-10000454        Furniture
# 3            Florida        33311  South  FUR-TA-10000577        Furniture
# 4            Florida        33311  South  OFF-ST-10000760  Office Supplies
# 12    North Carolina        28027  South  OFF-PA-10002365  Office Supplies
# ...              ...          ...    ...              ...              ...
# 9984        New York        11561   East  OFF-LA-10003766  Office Supplies
# 9985        New York        11561   East  OFF-SU-10000898  Office Supplies
# 9987         Georgia        30605  South  TEC-AC-10001539       Technology
# 9988         Georgia        30605  South  TEC-PH-10004006       Technology
# 9989         Florida        33180  South  FUR-FU-10001889        Furniture
#
#      sub_category                                       product_name  \
# 0       Bookcases                  Bush Somerset Collection Bookcase
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table
# 4         Storage                     Eldon Fold 'N Roll Cart System
# 12          Paper                                         Xerox 1967
# ...           ...                                                ...
# 9984       Labels                     Self-Adhesive Removable Labels
# 9985     Supplies  Acme Hot Forged Carbon Steel Scissors with Nic...
# 9987  Accessories  Logitech G430 Surround Sound Gaming Headset wi...
# 9988       Phones                    Panasonic KX - TS880B Telephone
# 9989  Furnishings                             Ultra Door Pull Handle
#
#          sales  quantity  discount    profit
# 0     261.9600         2      0.00   41.9136
# 1     731.9400         3      0.00  219.5820
# 3     957.5775         5      0.45 -383.0310
# 4      22.3680         2      0.20    2.5164
# 12     15.5520         3      0.20    5.4432
# ...        ...       ...       ...       ...
# 9984   31.5000        10      0.00   15.1200
# 9985   55.6000         4      0.00   16.1240
# 9987   79.9900         1      0.00   28.7964
# 9988  206.1000         5      0.00   55.6470
# 9989   25.2480         3      0.20    4.1028
#
# [7008 rows x 20 columns]

# %%
# cek quantity yang berjumlah antar 3 hingga 7
# df[(df['quantity'] >= 3) & (df['quantity'] <= 7)]
df[df['quantity'].between(3,7)]
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5     CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6     CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7     CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# ...              ...         ...         ...             ...         ...
# 9982  US-2016-157728   9/22/2016   9/28/2016  Standard Class    RC-19960
# 9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class    DV-13465
# 9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
#
#          customer_name    segment        country             city       state  \
# 1          Claire Gute   Consumer  United States        Henderson    Kentucky
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 5      Brosina Hoffman   Consumer  United States      Los Angeles  California
# 6      Brosina Hoffman   Consumer  United States      Los Angeles  California
# 7      Brosina Hoffman   Consumer  United States      Los Angeles  California
# ...                ...        ...            ...              ...         ...
# 9982        Ryan Crowe   Consumer  United States     Grand Rapids    Michigan
# 9985  Dianna Vittorini   Consumer  United States       Long Beach    New York
# 9988      Ruben Ausman  Corporate  United States           Athens     Georgia
# 9989  Tom Boeckenhauer   Consumer  United States            Miami     Florida
# 9992       Dave Brooks   Consumer  United States       Costa Mesa  California
#
#       postal_code   region       product_id         category sub_category  \
# 1           42420    South  FUR-CH-10000454        Furniture       Chairs
# 3           33311    South  FUR-TA-10000577        Furniture       Tables
# 5           90032     West  FUR-FU-10001487        Furniture  Furnishings
# 6           90032     West  OFF-AR-10002833  Office Supplies          Art
# 7           90032     West  TEC-PH-10002275       Technology       Phones
# ...           ...      ...              ...              ...          ...
# 9982        49505  Central  OFF-PA-10002195  Office Supplies        Paper
# 9985        11561     East  OFF-SU-10000898  Office Supplies     Supplies
# 9988        30605    South  TEC-PH-10004006       Technology       Phones
# 9989        33180    South  FUR-FU-10001889        Furniture  Furnishings
# 9992        92627     West  OFF-PA-10004041  Office Supplies        Paper
#
#                                            product_name     sales  quantity  \
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                            Newell 322    7.2800         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.1520         6
# ...                                                 ...       ...       ...
# 9982  RSVP Cards & Envelopes, Blank White, 8-1/2" X ...   35.5600         7
# 9985  Acme Hot Forged Carbon Steel Scissors with Nic...   55.6000         4
# 9988                    Panasonic KX - TS880B Telephone  206.1000         5
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
#
#       discount    profit
# 1         0.00  219.5820
# 3         0.45 -383.0310
# 5         0.00   14.1694
# 6         0.00    1.9656
# 7         0.20   90.7152
# ...        ...       ...
# 9982      0.00   16.7132
# 9985      0.00   16.1240
# 9988      0.00   55.6470
# 9989      0.20    4.1028
# 9992      0.00   13.3200
#
# [6008 rows x 20 columns]

# %% [markdown]
# ## Menambahkan Kolom dan menghapus kolom

# %% [markdown]
# Anggaplah kolom `sales` adalah harga total sebelum discount, maka kita dapat menghitung harga per unit dan membuat kolom baru.

# %%
# buatlah kolom unit_price
df['unit_price'] = df['sales'] / df['quantity']
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...  region       product_id         category sub_category  \
# 0  ...   South  FUR-BO-10001798        Furniture    Bookcases
# 1  ...   South  FUR-CH-10000454        Furniture       Chairs
# 2  ...    West  OFF-LA-10000240  Office Supplies       Labels
# 3  ...   South  FUR-TA-10000577        Furniture       Tables
# 4  ...   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit  unit_price
# 0      0.00   41.9136    130.9800
# 1      0.00  219.5820    243.9800
# 2      0.00    6.8714      7.3100
# 3      0.45 -383.0310    191.5155
# 4      0.20    2.5164     11.1840
#
# [5 rows x 21 columns]

# %%
# hapus kolom unit_price
df.drop(columns=['unit_price'], inplace=True)
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ## Menambahkan baris dan menghapus baris

# %%
# cek jumlah baris sebelum ditambahkan
df.shape
# Out:
# (9994, 20)

# %%
# misalkan kita ambil sample acak
data_dict= df.sample().to_dict(orient='list')
data_dict
# Out:
# {'order_id': ['CA-2016-143805'],
#  'order_date': ['12/1/2016'],
#  'ship_date': ['12/3/2016'],
#  'ship_mode': ['Second Class'],
#  'customer_id': ['JD-15895'],
#  'customer_name': ['Jonathan Doherty'],
#  'segment': ['Corporate'],
#  'country': ['United States'],
#  'city': ['Richmond'],
#  'state': ['Virginia'],
#  'postal_code': [23223],
#  'region': ['South'],
#  'product_id': ['OFF-AP-10002945'],
#  'category': ['Office Supplies'],
#  'sub_category': ['Appliances'],
#  'product_name': ["Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room"],
#  'sales': [2104.55],
#  'quantity': [7],
#  'discount': [0.0],
#  'profit': [694.5015]}

# %%
new_data= pd.DataFrame(data_dict)
new_data
# Out:
#          order_id order_date  ship_date     ship_mode customer_id  \
# 0  CA-2016-143805  12/1/2016  12/3/2016  Second Class    JD-15895
#
#       customer_name    segment        country      city     state  \
# 0  Jonathan Doherty  Corporate  United States  Richmond  Virginia
#
#    postal_code region       product_id         category sub_category  \
# 0        23223  South  OFF-AP-10002945  Office Supplies   Appliances
#
#                                         product_name    sales  quantity  \
# 0  Honeywell Enviracaire Portable HEPA Air Cleane...  2104.55         7
#
#    discount    profit
# 0       0.0  694.5015

# %%
# kita coba masukan data baru dari data_dict
df.loc[len(df)] = new_data.values[0]
df.tail()
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 9990  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914   5/4/2017   5/9/2017    Second Class    CC-12220
# 9994  CA-2016-143805  12/1/2016  12/3/2016    Second Class    JD-15895
#
#          customer_name    segment        country         city       state  \
# 9990       Dave Brooks   Consumer  United States   Costa Mesa  California
# 9991       Dave Brooks   Consumer  United States   Costa Mesa  California
# 9992       Dave Brooks   Consumer  United States   Costa Mesa  California
# 9993      Chris Cortes   Consumer  United States  Westminster  California
# 9994  Jonathan Doherty  Corporate  United States     Richmond    Virginia
#
#       postal_code region       product_id         category sub_category  \
# 9990        92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991        92627   West  TEC-PH-10003645       Technology       Phones
# 9992        92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993        92683   West  OFF-AP-10002684  Office Supplies   Appliances
# 9994        23223  South  OFF-AP-10002945  Office Supplies   Appliances
#
#                                            product_name     sales  quantity  \
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...    91.960         2
# 9991                              Aastra 57i VoIP phone   258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"    29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...   243.160         2
# 9994  Honeywell Enviracaire Portable HEPA Air Cleane...  2104.550         7
#
#       discount    profit
# 9990       0.0   15.6332
# 9991       0.2   19.3932
# 9992       0.0   13.3200
# 9993       0.0   72.9480
# 9994       0.0  694.5015

# %%
df.shape
# Out:
# (9995, 20)

# %%
# hapus 1 baris terakhir
df.drop(df.tail(1).index, inplace=True)
df.tail()
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 9989  CA-2014-110422  1/21/2014  1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914   5/4/2017   5/9/2017    Second Class    CC-12220
#
#          customer_name   segment        country         city       state  \
# 9989  Tom Boeckenhauer  Consumer  United States        Miami     Florida
# 9990       Dave Brooks  Consumer  United States   Costa Mesa  California
# 9991       Dave Brooks  Consumer  United States   Costa Mesa  California
# 9992       Dave Brooks  Consumer  United States   Costa Mesa  California
# 9993      Chris Cortes  Consumer  United States  Westminster  California
#
#       postal_code region       product_id         category sub_category  \
# 9989        33180  South  FUR-FU-10001889        Furniture  Furnishings
# 9990        92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991        92627   West  TEC-PH-10003645       Technology       Phones
# 9992        92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993        92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name    sales  quantity  \
# 9989                             Ultra Door Pull Handle   25.248         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       discount   profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
df.drop(index=9993)
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
#
#          customer_name    segment        country             city       state  \
# 0          Claire Gute   Consumer  United States        Henderson    Kentucky
# 1          Claire Gute   Consumer  United States        Henderson    Kentucky
# 2      Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...                ...        ...            ...              ...         ...
# 9988      Ruben Ausman  Corporate  United States           Athens     Georgia
# 9989  Tom Boeckenhauer   Consumer  United States            Miami     Florida
# 9990       Dave Brooks   Consumer  United States       Costa Mesa  California
# 9991       Dave Brooks   Consumer  United States       Costa Mesa  California
# 9992       Dave Brooks   Consumer  United States       Costa Mesa  California
#
#       postal_code region       product_id         category sub_category  \
# 0           42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1           42420  South  FUR-CH-10000454        Furniture       Chairs
# 2           90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3           33311  South  FUR-TA-10000577        Furniture       Tables
# 4           33311  South  OFF-ST-10000760  Office Supplies      Storage
# ...           ...    ...              ...              ...          ...
# 9988        30605  South  TEC-PH-10004006       Technology       Phones
# 9989        33180  South  FUR-FU-10001889        Furniture  Furnishings
# 9990        92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9991        92627   West  TEC-PH-10003645       Technology       Phones
# 9992        92627   West  OFF-PA-10004041  Office Supplies        Paper
#
#                                            product_name     sales  quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9988                    Panasonic KX - TS880B Telephone  206.1000         5
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
#
#       discount    profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9988      0.00   55.6470
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
#
# [9993 rows x 20 columns]

# %% [markdown]
# ## Grouping & Aggregation

# %%
# melihat rata-rata profit berdasarkan segment.
df.groupby('segment')['profit'].mean()
# Out:
# segment
# Consumer       25.836873
# Corporate      30.456667
# Home Office    33.818664
# Name: profit, dtype: float64

# %%
# melihat rata-rata profit berdasarkan segment menggunakan .agg
df.groupby('segment').agg({'profit': 'mean'})
# Out:
#                 profit
# segment
# Consumer     25.836873
# Corporate    30.456667
# Home Office  33.818664

# %%
# rata-rata dan median profit berdasarkan segment
df.groupby('segment').agg({'profit': ['mean', 'median']})
# Out:
#                 profit
#                   mean  median
# segment
# Consumer     25.836873  8.3754
# Corporate    30.456667  8.6940
# Home Office  33.818664  9.1020

# %%
# melihat jumlah nilai unik pada segment dan rata-rata profitnya
df.groupby('segment').agg({'profit': ['nunique', 'mean']})
# Out:
#              profit
#             nunique       mean
# segment
# Consumer       4273  25.836873
# Corporate      2644  30.456667
# Home Office    1610  33.818664

# %%
# rata-rata profit berdasarkan segment dan city
df.groupby(['segment', 'city'])['profit'].mean()
# Out:
# segment      city
# Consumer     Aberdeen         6.630000
#              Abilene         -3.758400
#              Akron          -11.610200
#              Albuquerque      9.628450
#              Alexandria      10.528933
#                                ...
# Home Office  Wilmington     133.970367
#              Wilson          -5.412000
#              Woodstock        0.910000
#              Yonkers         47.312600
#              Yuma          -257.936400
# Name: profit, Length: 1026, dtype: float64

# %% [markdown]
# **Sekarang cobalah lakukan proses untuk "Mencari city (kota) yang memiliki profit paling tinggi pada setiap segment."**
